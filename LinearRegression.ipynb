# %% [markdown]
# # **TASK 1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# @title Importing the Dataset
import pandas as pd
car=pd.read_csv('CarPrice_Assignment.csv')

# %%
# @title Checking for Null Values
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# @title Checking fot Duplicate Rows
car.duplicated().sum()
# Out:
# 0

# %%
# @title Dataset Description
car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# @title Dataset Rows
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# @title Distribution of Car Prices HistPlot
plt.figure(figsize=(8, 6))
sns.histplot(car['price'], kde=True,color='green')
plt.title('Distribution of Car Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# @title Car Engine Size vs. Price ScatterPlot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='enginesize', y='price', data=car, color='orange')
plt.title('Car Engine Size vs. Price')
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.show()

# %%
# @title Fuel Type Box Plot w.r.t Price BoxPlot
plt.figure(figsize=(8, 6))
sns.boxplot(x='fueltype', y='price', data=car, color='grey')
plt.title('Fuel Type Box Plot w.r.t Price')
plt.xlabel('Fuel Type')
plt.ylabel('Price')
plt.show()

# %%
# @title Aspiration Count
sns.countplot(x='aspiration',data=car,color='brown')
plt.title('Count of Aspiration')
plt.xlabel('Aspiration')
plt.ylabel('Count')
plt.show()

# %%
# @title Door Number Count
sns.countplot(x='doornumber',data=car,color='yellow')
plt.title('Count of No. of Doors')
plt.xlabel('No. of Doors')
plt.ylabel('Count')
plt.show()

# %%
# @title MPG vs Price ScatterPlot
plt.scatter(car['citympg'], car['price'], color='lightcoral', label='City MPG')
plt.scatter(car['highwaympg'], car['price'], color='lightgreen', label='Highway MPG')
plt.title('MPG vs Price')
plt.xlabel('MPG')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# @title Selecting Categoric Columns
cc=car.select_dtypes(include=['object']).columns
print(cc)
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
# @title Unique Values in Categoric Columns
for i in cc:
  print(i)
  print(car[i].unique())
# Out:
# CarName
# ['alfa-romero giulia' 'alfa-romero stelvio' 'alfa-romero Quadrifoglio'
#  'audi 100 ls' 'audi 100ls' 'audi fox' 'audi 5000' 'audi 4000'
#  'audi 5000s (diesel)' 'bmw 320i' 'bmw x1' 'bmw x3' 'bmw z4' 'bmw x4'
#  'bmw x5' 'chevrolet impala' 'chevrolet monte carlo' 'chevrolet vega 2300'
#  'dodge rampage' 'dodge challenger se' 'dodge d200' 'dodge monaco (sw)'
#  'dodge colt hardtop' 'dodge colt (sw)' 'dodge coronet custom'
#  'dodge dart custom' 'dodge coronet custom (sw)' 'honda civic'
#  'honda civic cvcc' 'honda accord cvcc' 'honda accord lx'
#  'honda civic 1500 gl' 'honda accord' 'honda civic 1300' 'honda prelude'
#  'honda civic (auto)' 'isuzu MU-X' 'isuzu D-Max ' 'isuzu D-Max V-Cross'
#  'jaguar xj' 'jaguar xf' 'jaguar xk' 'maxda rx3' 'maxda glc deluxe'
#  'mazda rx2 coupe' 'mazda rx-4' 'mazda glc deluxe' 'mazda 626' 'mazda glc'
#  'mazda rx-7 gs' 'mazda glc 4' 'mazda glc custom l' 'mazda glc custom'
# ...

# %%
# @title Label Encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cc:
  car[i]=le.fit_transform(car[i])

# %%
# @title Splitting into X and Y
x=car.drop('price',axis=1)
y=car['price']

# %%
# @title Heatmap
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,12))
corr=x.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
# @title Correlation With Target
corr1=x.corrwith(y).sort_values(ascending=False)
corr1
# Out:
# enginesize          0.874145
# curbweight          0.835305
# horsepower          0.808139
# carwidth            0.759325
# carlength           0.682920
# drivewheel          0.577992
# wheelbase           0.577816
# boreratio           0.553173
# fuelsystem          0.526823
# enginelocation      0.324973
# aspiration          0.177926
# carheight           0.119336
# stroke              0.079443
# compressionratio    0.067984
# enginetype          0.049171
# cylindernumber     -0.027628
# doornumber         -0.031835
# symboling          -0.079978
# carbody            -0.083976
# peakrpm            -0.085267
# fueltype           -0.105679
# car_ID             -0.109093
# CarName            -0.231439
# citympg            -0.685751
# highwaympg         -0.697599
# dtype: float64

# %%
# @title Dropping Irrelevant Features
dropped=corr1[abs(corr1)<0.1].index
x=x.drop(dropped,axis=1)
print(f"Dropped features: {dropped.tolist()}")
# Out:
# Dropped features: ['stroke', 'compressionratio', 'enginetype', 'cylindernumber', 'doornumber', 'symboling', 'carbody', 'peakrpm']

# %%
# @title Dropping ID
x=x.drop('car_ID',axis=1)

# %%
# @title Train Test Split
import numpy as np
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# @title Data Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
# @title Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
lr=LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# @title Training VS Testing Results
pred=lr.predict(xtest)
r2=r2_score(ytest,pred)
print("Testing Results:")
print(f"R-Squared:{r2:.3f}")
print(f"Mean Squared Error: {mean_squared_error(ytest, pred):.3f}")
print("\nTraining Results:")
predtr=lr.predict(xtrain)
r2tr=r2_score(ytrain,predtr)
print(f"R-Squared:{r2tr:.3f}")
print(f"Mean Squared Error: {mean_squared_error(ytrain, predtr):.3f}")
# Out:
# Testing Results:
# R-Squared:0.856
# Mean Squared Error: 11399152.967
#
# Training Results:
# R-Squared:0.890
# Mean Squared Error: 6536463.767

# %%
# @title Train Test Graphs
plt.figure(figsize=(8,6))
plt.scatter(ytest, pred, alpha=0.6, color='darkgreen',label='Test')
plt.scatter(ytrain, predtr, alpha=0.6, color='darkblue',label='Train')
plt.plot([min(ytest.min(),ytrain.min()),max(ytest.max(),ytrain.max())],[min(ytest.min(),ytrain.min()),max(ytest.max(),ytrain.max())],'r--')
plt.title('Training and Testing Predictions')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **TASK 2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
bill=pd.read_csv('electricity_bill_dataset.csv')

# %%
bill.head(5)
# Out:
#    Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  Month  \
# 0   16          23.0             2.0         6.0      1.0          0     10
# 1   19          22.0             2.0         3.0      1.0          0      5
# 2    7          20.0             2.0         6.0      7.0          0      7
# 3    7          22.0             3.0        21.0      1.0          0      6
# 4   11          23.0             2.0        11.0      1.0          0      2
#
#         City                                    Company  MonthlyHours  \
# 0  Hyderabad                    Tata Power Company Ltd.           384
# 1   Vadodara                                       NHPC           488
# 2     Shimla                            Jyoti Structure           416
# 3     Mumbai                            Power Grid Corp           475
# 4     Mumbai  Ratnagiri Gas and Power Pvt. Ltd. (RGPPL)           457
#
#    TariffRate  ElectricityBill
# 0         8.4           3225.6
# ...

# %%
bill.isnull().sum()
# Out:
# Fan                0
# Refrigerator       0
# AirConditioner     0
# Television         0
# Monitor            0
# MotorPump          0
# Month              0
# City               0
# Company            0
# MonthlyHours       0
# TariffRate         0
# ElectricityBill    0
# dtype: int64

# %%
bill.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
cc=bill.select_dtypes(include=['object']).columns
le=LabelEncoder()
for i in cc:
  bill[i]=le.fit_transform(bill[i])

# %%
x=bill.drop('ElectricityBill',axis=1)
y=bill['ElectricityBill']

# %%
corr2=x.corrwith(y).sort_values(ascending=False)
corr2
# Out:
# MonthlyHours      0.958702
# Television        0.412651
# Fan               0.410682
# Refrigerator      0.376816
# Monitor           0.309986
# TariffRate        0.286226
# AirConditioner    0.261845
# Month             0.036316
# Company           0.001670
# City             -0.021603
# MotorPump              NaN
# dtype: float64

# %% [markdown]
# **MonthlyHours has a strong Linear relationship with the target. Television, Fan, Refrigerator, Monitor, TariffRate, AirConditioner, Month have a moderate linear relationship which is not strong enough to fully depend on linearity alone. Month, Company, and City do not have a linear relationship with the target. MotorPump has no relationship with the target.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr=x.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Multicollinearity does not exist because the features are not highly correlated amogst them selves**

# %%
xcol=x.columns
for c in xcol:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=c, y='ElectricityBill', data=bill, color='orange')
    plt.title(f'Relationship between {c} and Electricity Bill')
    plt.xlabel(c)
    plt.ylabel('Electricity Bill')
    plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)
lr=LinearRegression()
lr.fit(xtrain,ytrain)
pred=lr.predict(xtest)
r2=r2_score(ytest,pred)
print("Testing Results:")
print(f"R-Squared:{r2:.3f}")
print(f"Mean Squared Error: {mean_squared_error(ytest, pred):.3f}")
# Out:
# Testing Results:
# R-Squared:0.996
# Mean Squared Error: 4970.296

# %%
residuals = ytest - pred
plt.figure(figsize=(8, 6))
sns.residplot(x=pred,y=residuals,lowess=True ,color='salmon',line_kws={'color': 'black', 'lw': 1})
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.grid()
plt.show()

# %% [markdown]
# **Data doesnot display Homoscedasticity because the residuals are not random, and the residual plot shows a pattern.**

# %% [markdown]
# **This shape also violates Linearity**

# %%
plt.figure(figsize=(8, 6))
plt.hist(residuals, bins=20, color='skyblue', edgecolor='black')
plt.title('Residual Histogram')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# **Residuals are normally distributed**

# %%
import matplotlib.pyplot as plt
hours=x2.iloc[:,9]
plt.figure(figsize=(10, 6))
plt.scatter(hours[:-1], residuals[1:], alpha=0.7, label='Lagged Residuals')
plt.title('Lagged Scatter Plot of Residuals vs. Monthly Hours')
plt.ylabel('Residuals')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Independacy is valid due to random pattern**

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
xtrain_poly, xtest_poly, ytrain, ytest=train_test_split(x_poly, y, test_size=0.2, random_state=42)
sc = StandardScaler()
xtrain_poly = sc.fit_transform(xtrain_poly)
xtest_poly = sc.transform(xtest_poly)
lr_poly = LinearRegression()
lr_poly.fit(xtrain_poly, ytrain)
pred_poly = lr_poly.predict(xtest_poly)
r2_poly = r2_score(ytest, pred_poly)
print("Polynomial Regression - Testing Results:")
print(f"R-Squared: {r2_poly:.3f}")
print(f"Mean Squared Error: {mean_squared_error(ytest, pred_poly):.3f}")
# Out:
# Polynomial Regression - Testing Results:
# R-Squared: 1.000
# Mean Squared Error: 0.000

# %% [markdown]
# # So by looking at all the Assumptions and applying Polynomial Regression to the dataset we can say that some of the assumptions are valid, while some are violated. Altough Linear Regression is giving good r2 score, we can apply linear regression but other models work better as assumptions are being violated for linear regression. This can be verified after we applied polynomial regression and it gave better results.
